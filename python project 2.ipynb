# %% [markdown]
# # Welcome to RESHMA'S RESTAURANT🥗🌱

# %%
menu = {
    "Pizza":50,
    "Pasta":70,
    "Burger":40,
    "Cold Coffee":50,
    "Salad":30,
}

print("Welcome to RESHMA'S RESTAURANT")
print("Pizza: Rs50\nPasta: Rs70\nBurger: Rs40\nCold Coffee: Rs50\nSalad :30")

order_total = 0
item_1 = input("Dear customer Enter the name of item you want to order=")
if item_1 in menu:
    order_total += menu[item_1]
    print("Your item",item_1,"has been added to your order")

else:
    print("Please order something else we can serve you 🥘")

another_order = input("Hey😋! do you want to add another item?")  
if another_order == "Yes":
    item_2 = input(" Ohh that's Great🤩! Enter the name of second item =")
    if item_2 in menu:
        order_total +=menu[item_2]
        print("Your item",item_2,"has been added to your order")
    else:
        print(" SORRY 😞 Ordered item is not available !")
print("The total amount of items to pay is",order_total)
# Out:
# Welcome to RESHMA'S RESTAURANT
# Pizza: Rs50
# Pasta: Rs70
# Burger: Rs40
# Cold Coffee: Rs50
# Salad :30
# Dear customer Enter the name of item you want to order= Pizza
# Your item Pizza has been added to your order
# Hey😋! do you want to add another item? Yes
#  Ohh that's Great🤩! Enter the name of second item = Salad
# Your item Salad has been added to your order
# The total amount of items to pay is 80
